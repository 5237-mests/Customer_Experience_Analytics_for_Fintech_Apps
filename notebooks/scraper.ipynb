# %% [markdown]
# <a href="https://colab.research.google.com/github/5237-mests/Customer_Experience_Analytics_for_Fintech_Apps/blob/task-1/notebooks/scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install google-play-scraper

# %%
from google_play_scraper import reviews, app, Sort, reviews_all
import pandas as pd
from datetime import datetime

# %%
result_dashen = app(
    'com.dashen.dashensuperapp',
    lang='en',
    country='us'
)

# %%
# result_dashen

# %%
result_boa = app(
    'com.boa.boaMobileBanking',
    lang='en',
    country='us'
)

# %%
# result_boa

# %%
result = app(
    'com.combanketh.mobilebanking',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# %%
# result

# %% [markdown]
# # Scrape for CBE

# %%
def fetch_reviews(app_id, bank_name, max_reviews=440):
    all_reviews = []
    count = 0
    token = None

    while count < max_reviews:
        result, token = reviews(
            app_id,
            lang='en',
            country='us',
            count=100,
            continuation_token=token
        )
        for r in result:
            all_reviews.append({
                'review': r['content'],
                'rating': r['score'],
                'date': r['at'].strftime('%Y-%m-%d'),
                'bank': bank_name,
                'source': 'Google Play'
            })
        count = len(all_reviews)
        if not token:
            break

    return pd.DataFrame(all_reviews)

# %%
# Fetchh reviews for CBE
app_id = "com.combanketh.mobilebanking"
bank = "Commercial Bank of Ethiopia"
cbe_df = fetch_reviews(app_id, bank)
cbe_df.to_csv("raw_cbe_bank_reviews.csv", index=False)
print("Saved reviews")
# Out:
# Saved reviews

# %%
cbe_df.tail()
# Out:
#                                                 review  rating        date  \
# 995                                  its excellent app       5  2025-01-23
# 996  After a recent update, this app stopped workin...       3  2025-01-23
# 997  እብድ ባነክ፣ ይሄ ዝምብሎ Update ብቻ የሚለውን እና Update የማያ...       1  2025-01-23
# 998  I am students of accounting and finance when i...       5  2025-01-23
# 999                    wow . what i can say thank you.       5  2025-01-23
#
#                             bank       source
# 995  Commercial Bank of Ethiopia  Google Play
# 996  Commercial Bank of Ethiopia  Google Play
# 997  Commercial Bank of Ethiopia  Google Play
# 998  Commercial Bank of Ethiopia  Google Play
# 999  Commercial Bank of Ethiopia  Google Play

# %% [markdown]
# # Scrape for Dashen Bank

# %%
# Fetchh reviews for Dashen Bank
app_id = "com.dashen.dashensuperapp"
bank = "Dashen Bank"
dashen_df = fetch_reviews(app_id, bank)
dashen_df.to_csv("raw_dashen_bank_reviews.csv", index=False)
print("Saved reviews")

# %%
dashen_df
# Out:
#                                                 review  rating        date  \
# 0                                                 love       3  2025-06-05
# 1                                                 መቸሸጠ       5  2025-06-03
# 2                                                  wow       5  2025-06-03
# 3                                                gadaa       5  2025-06-01
# 4                  Massive upgrade from the Amole app.       5  2025-05-31
# ..                                                 ...     ...         ...
# 443                                               Best       5  2025-01-13
# 444  Waw Great and innovated,user friendly, always ...       5  2025-01-13
# 445                                   It's Best waww 🙏       5  2025-01-13
# 446                              Always one step ahead       5  2025-01-13
# 447       Like Me, I Hope It Works Better Than Before.       5  2025-01-11
#
#             bank       source
# 0    Dashen Bank  Google Play
# ...

# %%
# result = reviews_all(
#     'com.dashen.dashensuperapp',
#     sleep_milliseconds=0, # defaults to 0
#     lang='en', # defaults to 'en'
#     country='us', # defaults to 'us'
#     sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
#     filter_score_with=5 # defaults to None(means all score)
# )

# %%
# result

# %%
# all_reviews = []
# bank_name = 'Dashen Bank'

# for r in result:
#     all_reviews.append({
#         'review': r['content'],
#         'rating': r['score'],
#         'date': r['at'].strftime('%Y-%m-%d'),
#         'bank': bank_name,
#         'source': 'Google Play'
#     })

# %%
# create dataframe for dashen
# dashen_df = pd.DataFrame(all_reviews)

# %%
# save to csv
# dashen_df.to_csv('raw_dashen_bank_reviews.csv', index=False)

# %%
# dashen_df

# %% [markdown]
# # Scrape for BOA

# %%
# BOA
app_id = "com.boa.boaMobileBanking"
bank = "Bank of Abysinia"
boa_df = fetch_reviews(app_id, bank)
boa_df.to_csv("raw_boa_bank_reviews.csv", index=False)

# %%
boa_df.tail()
# Out:
#                                                 review  rating        date  \
# 995  I don't have words for your great work.. Reall...       5  2024-02-03
# 996                                               Nice       5  2024-02-03
# 997  A massive improvement from the previous app. M...       5  2024-02-03
# 998                                               Good       5  2024-02-03
# 999                                                Boa       5  2024-02-03
#
#                  bank       source
# 995  Bank of Abysinia  Google Play
# 996  Bank of Abysinia  Google Play
# 997  Bank of Abysinia  Google Play
# 998  Bank of Abysinia  Google Play
# 999  Bank of Abysinia  Google Play

# %% [markdown]
# # Preprocessing

# %% [markdown]
# #### Clean cbe review data

# %%
import pandas as pd

# Load cbe raw reviews from csv
cbe_df = pd.read_csv("raw_cbe_bank_reviews.csv")

cbe_df.tail()
# Out:
#                                                 review  rating        date  \
# 995                                  its excellent app       5  2025-01-23
# 996  After a recent update, this app stopped workin...       3  2025-01-23
# 997  እብድ ባነክ፣ ይሄ ዝምብሎ Update ብቻ የሚለውን እና Update የማያ...       1  2025-01-23
# 998  I am students of accounting and finance when i...       5  2025-01-23
# 999                    wow . what i can say thank you.       5  2025-01-23
#
#                             bank       source
# 995  Commercial Bank of Ethiopia  Google Play
# 996  Commercial Bank of Ethiopia  Google Play
# 997  Commercial Bank of Ethiopia  Google Play
# 998  Commercial Bank of Ethiopia  Google Play
# 999  Commercial Bank of Ethiopia  Google Play

# %%
# check dublicates
cbe_df.duplicated().sum()
# Out:
# np.int64(35)

# %%
# Drop duplicates
cbe_df.drop_duplicates(subset=["review", "bank"], inplace=True)

# %%
# Drop empty reviews
cbe_df.dropna(subset=["review", "rating", "date"], inplace=True)

# %%
# Format date to YYYY-MM-DD (already done in scraping)
cbe_df['date'] = pd.to_datetime(cbe_df['date']).dt.strftime('%Y-%m-%d')

# %%
# Final structure
cbe_df = cbe_df[["review", "rating", "date", "bank", "source"]]

# Save cleaned version
cbe_df.to_csv("cleaned_cbe_bank_reviews.csv", index=False)

print(f"✅ Final dataset shape: {cbe_df.shape}")
# Out:
# ✅ Final dataset shape: (741, 5)

# %% [markdown]
# #### Clean dashen review data

# %%
# load dashen csv file
dashen_df = pd.read_csv("raw_dashen_bank_reviews.csv")

# %%
dashen_df.tail()
# Out:
#          review  rating        date         bank       source
# 357         wow       5  2025-05-13  Dashen Bank  Google Play
# 358     Pro max       5  2025-01-17  Dashen Bank  Google Play
# 359    wow appl       5  2025-04-28  Dashen Bank  Google Play
# 360     wow apo       5  2025-05-15  Dashen Bank  Google Play
# 361  wowwwe app       5  2025-05-17  Dashen Bank  Google Play

# %%
# check dublicates
dashen_df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Drop duplicates
dashen_df.drop_duplicates(subset=["review", "bank"], inplace=True)

# %%
# Drop empty reviews
dashen_df.dropna(subset=["review", "rating", "date"], inplace=True)

# %%
# Format date to YYYY-MM-DD
dashen_df['date'] = pd.to_datetime(cbe_df['date']).dt.strftime('%Y-%m-%d')

# %%
# Final structure
dashen_df = dashen_df[["review", "rating", "date", "bank", "source"]]

# Save cleaned version
dashen_df.to_csv("cleaned_dashen_bank_reviews.csv", index=False)

print(f"✅ Final dataset shape: {dashen_df.shape}")
# Out:
# ✅ Final dataset shape: (325, 5)

# %% [markdown]
# #### Clean BOA review data

# %%
# load boa csv file
boa_df = pd.read_csv("raw_boa_bank_reviews.csv")

# %%
boa_df.tail()
# Out:
#                                                 review  rating        date  \
# 995  I don't have words for your great work.. Reall...       5  2024-02-03
# 996                                               Nice       5  2024-02-03
# 997  A massive improvement from the previous app. M...       5  2024-02-03
# 998                                               Good       5  2024-02-03
# 999                                                Boa       5  2024-02-03
#
#                  bank       source
# 995  Bank of Abysinia  Google Play
# 996  Bank of Abysinia  Google Play
# 997  Bank of Abysinia  Google Play
# 998  Bank of Abysinia  Google Play
# 999  Bank of Abysinia  Google Play

# %%
# check dublicates
dashen_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Drop empty reviews
boa_df.dropna(subset=["review", "rating", "date"], inplace=True)

# %%
# Format date to YYYY-MM-DD
boa_df['date'] = pd.to_datetime(boa_df['date']).dt.strftime('%Y-%m-%d')

# %%
# Final structure
boa_df = boa_df[["review", "rating", "date", "bank", "source"]]

# Save cleaned version
boa_df.to_csv("cleaned_boa_bank_reviews.csv", index=False)

print(f"✅ Final dataset shape: {boa_df.shape}")
# Out:
# ✅ Final dataset shape: (1000, 5)
